# %% [markdown]
# ### Third game : Smart Human to computer

# %% [markdown]
# ####   ---------------    computer will  play smart   ------------------------------

# %% [markdown]
# #### ---------------  either play to make the user lose
# #### --------------   or play to make him self  "computer" win

# %% [markdown]
# ### the design of this game will be the same as Human to computer game.
#
# ### except the function `play_computer` is no longer exist.
# ### (   `play_computer_smart `    &   `study_player1_movement`    &    `play_to_win`)will take it's role .

# %% [markdown]
# ### the purpose of `play_computer_smart`  function is :
# - called from main fuction after player_1 play his turn.
# - go to call (`study_player1_movement`)function  to study the user1 how he play his movement
# - decide based  on the refurn from (`study_player1_movement`)function, orient the code if the player will  win in his next move computer decide to play to make player1 lose,
# if the player just play normal movement  without any chance of winning, the computer decide to play to win the game.
#
# -

# %% [markdown]
# ### the purpose of `study_player1_movement`  function is :
# - the main focse is to  study the user movement and predict how he will when and return the correct movement to the `play_computer_smart` fuction to make the player lose
#
# - stuy the player1 previous movement.
# .
#
#  ==> if the user just play random or normal move, it's return 0 value mean that("the user will not win this turn ")
#
#  ==> if the user have a chance in winng the game, he will  retun value = number of squre in X & O table to let `play_computer_smart` fuction to lose the player

# %% [markdown]
# #### Note:
# - if the player want ot win the game,He has 8 way to win this game.
# - .
# - Each way has 3 different methods to apply.
#
# For example : if user want to win by makeing  ( x   x  x ) in the first row. he has 3 different way to achive.
# - ( x   x __ )   ( x __ x )  (__ x  x )
# - ( x   x  x  )    ( x   x  x )   ( x   x  x )
# - ( x   x  x  )    ( x   x  x )   ( x   x  x )
#
# - so we need to calculate 8*3 = 24 methods the user may be apply to win the computer.
#
# - If I programe the code for catch  the full 24 methods the game will be very very difficult and the use will no have any chance to win.
#
# - so I decided to only find out 3 of 24 methods, If the uers will choose  to win by one of these 3 mehtods the code will know that and will easly make the user lose.
# - any other methods the user will try to win he will wins isa.

# %% [markdown]
# ### the purpose of `play_to_win`  function is :
#
# #### - the oppsite purpose of ( `study_player1_movement`  ), the previous one focus on study the player movement and let him lose.
#
# #### - However the `play_to_win`focus only  on how to make computer win the game

# %% [markdown]
# ## (show_table ) function

# %%
def show_table(pos):
    print(f"\n_________________________________\n|          |          |          |\n|     {pos[0]}    |     {pos[1]}    |     {pos[2]}    |\n|          |          |          |\n_________________________________\n|          |          |          |\n|     {pos[3]}    |     {pos[4]}    |     {pos[5]}    |\n|          |          |          | \n_________________________________\n|          |          |          |\n|     {pos[6]}    |     {pos[7]}    |     {pos[8]}    |\n|          |          |          | \n_________________________________\n")

# %% [markdown]
# ## (update_table) function

# %%
def update_table(user_input,user):
    if user == 1:
        for i in range(9):
            if i+1 == user_input:
                pos[i]= "X"              
            else:
                continue
                
    # the user 3 is the computer            
    elif user==3:
        for i in range(9):
            if i+1 == user_input:
                pos[i]= "O"                
            else:
                continue
    else:
        print("I can not update  the table with user input")

# %% [markdown]
# ## (check_winner) function

# %%
def check_winner(pos,user,result): 
    print(pos)
    #print(f"user value is {user}")
    if user == 1:
        #print("I am inside user 1 for checking ")
        #print(f"the result is {result}")
        for i in range(8):
            if (pos[0] == pos[1]==pos[2] == "X"):
                print("user1 : win the game1")
                result= "user_1 win the game"
                break
            elif(pos[3] == pos[4]==pos[5] == "X"):
                print("user : 1 win the game2")
                result= "user_1 win the game"
                break
            
            elif(pos[6] == pos[7]==pos[8] == "X"):
                print("user : 1 win the game3")
                result= "user_1 win the game"
                break
                
            elif(pos[0] == pos[3]==pos[6] == "X"):
                print("user : 1 win the game4")
                result= "user_1 win the game"
                break
            
            elif(pos[1] == pos[4]==pos[7] == "X"):
                print("user : 1 win the game5")
                result= "user_1 win the game"
                break
            elif(pos[2] == pos[5]==pos[8] == "X"):
                print("user : 1 win the game6")
                result= "user_1 win the game"
                break
            
            elif(pos[0] == pos[4]==pos[8] == "X"):
                print("user : 1 win the game7")
                result= "user_1 win the game"
                break
            
            elif(pos[2] == pos[4]==pos[6] == "X"):
                print("user : 1 win the game8")
                result= "user_1 win the game"
                break            
            else:
                pass
                #print("something wrong while calculating the user 1 statue")
                
    #here i will chech if the random input from the computer make a good movement and win the game or just random move from computer 
    elif user ==3:
        #print("I am inside computer  for cheching  ")
        #print(f"the result is {result}")
        for i in range(8):
            if (pos[0] == pos[1]==pos[2] == "O"):
                print("Computer  win the game1")
                result= "Computer win the game"
                break
            elif(pos[3] == pos[4]==pos[5] == "O"):
                print("user : 2 win the game2")
                result= "Computer win the game"
                break
            
            elif(pos[6] == pos[7]==pos[8] == "O"):
                print("user : 2 win the game3")
                result= "Computer win the game"
                break
                
            elif(pos[0] == pos[3]==pos[6] == "O"):
                print("user : 2 win the game4")
                result= "Computer win the game"
                break
            
            elif(pos[1] == pos[4]==pos[7] == "O"):
                print("user : 2 win the game5")
                result= "Computer win the game"
                break
            elif(pos[2] == pos[5]==pos[8] == "O"):
                print("user : 2 win the game6")
                result= "Computer win the game"
                break
            
            elif(pos[0] == pos[4]==pos[8] == "O"):
                print("user : 2 win the game7")
                result= "Computer win the game"
                break
            
            elif(pos[2] == pos[4]==pos[6] == "O"):
                print("user : 2 win the game8")
                result= "Computer win the game"
                break
            else:
                pass
                #print("something wrong while calculating the user 2 statue")
        
        
    
    else:
        print(" I can not find out who is the winner ")
    
    #print(f"the result in the last if is::: {result}")
    return result

# %% [markdown]
# ## (play_user1) fuction

# %%
def play_user1(user,result):
    user_input=int(input("User 1   Play  "))
    update_table(user_input,user)
    show_table(pos)
    result=check_winner(pos,user,result)
    #print(f"the result in the play _user1 functions is ::{result}")
    return result

# %% [markdown]
# ## (study_player1_movement) fuction

# %%
#I will study the player1 movement to let him lose

def study_player1_movement():
    
    print("I am inside (study_player_movement) fuction to know,, how the player1 play his movement")
    print(f"the current position is : {pos}")
    for i in range(25):
        if (pos[0]==pos[1]== 'X'):
            print(f"take care the Player1 may be win, Computer have to play on {pos[2]} ")
            comp_input=pos[2]
            break
        elif (pos[0]==pos[2]=='X'):
            print(f"take care the Player1 may be win, Computer have to play on {pos[1]} ")
            comp_input=pos[1]
            break
        elif (pos[1]==pos[2]=='X'):
            print(f"take care the Player1 may be win, Computer have to play on {pos[0]} ")
            comp_input=pos[0]
            break
        else:
            comp_input=0
            print("the user will not win this turn ")
    print(f"the computer input after study is {comp_input} ,, I am in study_player1_movement ")        
    return comp_input

# %% [markdown]
# ## (play_to_win) fuction

# %%
def play_to_win():
        # here I compter do his best to find the good movement to win the game 
        #I will come here at 2 positions:
        #1- after computer study the player movement and find no chance for player to win 
        #2- if the computer input movement play a movement which is already occupied 
        # I am looking for empty places to play on 
        
        position_empty=[]
        for value in pos: 
            if (value == "X") or (value == "O"):
                print ("X or O value ")
            else:
                position_empty.append(value)
                print("value is number ")
        print(f"empty postion is {position_empty}")
        #the computer input 
        comp_input=random.choice(position_empty)
        print (f"computer will play   {comp_input}") 
        return comp_input

# %% [markdown]
# ## (play_computer_smart) fuction

# %%
import random 
def play_computer_smart(user,result):
    
    print(f"the all position is :{pos}")
    
    # I will go to study the player1 movement to make him lose the game
    
    comp_input=study_player1_movement()
    print(f"the computer_ input after study is : {comp_input} I am in (play_computer_smart) function ")
    
    if (comp_input==0):
        #I will  going to study the  table positions to let me as a computer to win 
        comp_input=play_to_win()
        
    elif  (comp_input=="O") or (comp_input=="X"):
        #I will  going to study the  table positions to let me as a computer to win 
        comp_input=play_to_win()
                

    
    update_table(comp_input,user)
    show_table(pos)
    result=check_winner(pos,user,result)
    return result

# %% [markdown]
# ###   my main function

# %%
global user
global pos

pos=[1,2,3,4,5,6,7,8,9]
show_table(pos)
result ="No one win the game, continue playing "    

for i in range(5):
    print(f"  Round : {i+1}  ,in the game ")
    user=1
    result =play_user1(user,result)
    #print(f"the result in the main_player1 is : {result}")
    
    if result == "user_1 win the game":
        print("user_1 win the game,,  I will going to finish the game ")
        break
    else:
        print ("the game is still working ")
        
    user=3
    #user =3 mean the computer will play 
    result=play_computer_smart(user,result)
    #print(f"the result in the main_computer is : {result}")
    if result == "Computer win the game":
        print("Computer win the game,,  I will going to finish the game ")
        break
    else:
        print ("the game is still working ")

print(" The game is  finished ")
# Out:
# _________________________________
# |          |          |          |
# |     1    |     2    |     3    |
# |          |          |          |
# _________________________________
# |          |          |          |
# |     4    |     5    |     6    |
# |          |          |          |
# _________________________________
# |          |          |          |
# |     7    |     8    |     9    |
# |          |          |          |
# _________________________________
#
#   Round : 1  ,in the game
# User 1   Play  1
#
# _________________________________
# |          |          |          |
# |     X    |     2    |     3    |
# |          |          |          |
# _________________________________
# |          |          |          |
# |     4    |     5    |     6    |
# |          |          |          |
# _________________________________
# |          |          |          |
# |     7    |     8    |     9    |
# |          |          |          |
# ...
