# %% [markdown]
# ### Second game : Human  to Computer

# %% [markdown]
# ####   ---------------    computer will  randomly play  ------------------------------

# %% [markdown]
# #### the design of this game will be the same as the human to human game.
# .
# #### except the function `play_user2` is no longer exist  and `play_computer` will take it's role .

# %% [markdown]
# ### the purpose of `play_computer`  function is :
#
# - will do  what function `play_user2` make , inaddition will make one step instead.
# .
# - instead  take the movement from user 2 . `play_computer` function will find out the empty positions in the x_o table. and randmly take one of these empty positions to play it as an input from second player . this description is what happen in `play_comptuer` function code form line (4-15)

# %%
def show_table(pos):
    print(f"\n_________________________________\n|          |          |          |\n|     {pos[0]}    |     {pos[1]}    |     {pos[2]}    |\n|          |          |          |\n_________________________________\n|          |          |          |\n|     {pos[3]}    |     {pos[4]}    |     {pos[5]}    |\n|          |          |          | \n_________________________________\n|          |          |          |\n|     {pos[6]}    |     {pos[7]}    |     {pos[8]}    |\n|          |          |          | \n_________________________________\n")

# %%
def update_table(user_input,user):
    if user == 1:
        for i in range(9):
            if i+1 == user_input:
                pos[i]= "X"              
            else:
                continue
                
    # the user 3 is the computer            
    elif user==3:
        for i in range(9):
            if i+1 == user_input:
                pos[i]= "O"                
            else:
                continue
    else:
        print("I can not update  the table with user input")

# %%
def check_winner(pos,user,result): 
    print(pos)
    print(f"user value is {user}")
    if user == 1:
        print("I am inside user 1 for checking ")
        print(f"the result is {result}")
        for i in range(8):
            if (pos[0] == pos[1]==pos[2] == "X"):
                print("user1 : win the game1")
                result= "user_1 win the game"
                break
            elif(pos[3] == pos[4]==pos[5] == "X"):
                print("user : 1 win the game2")
                result= "user_1 win the game"
                break
            
            elif(pos[6] == pos[7]==pos[8] == "X"):
                print("user : 1 win the game3")
                result= "user_1 win the game"
                break
                
            elif(pos[0] == pos[3]==pos[6] == "X"):
                print("user : 1 win the game4")
                result= "user_1 win the game"
                break
            
            elif(pos[1] == pos[4]==pos[7] == "X"):
                print("user : 1 win the game5")
                result= "user_1 win the game"
                break
            elif(pos[2] == pos[5]==pos[8] == "X"):
                print("user : 1 win the game6")
                result= "user_1 win the game"
                break
            
            elif(pos[0] == pos[4]==pos[8] == "X"):
                print("user : 1 win the game7")
                result= "user_1 win the game"
                break
            
            elif(pos[2] == pos[4]==pos[6] == "X"):
                print("user : 1 win the game8")
                result= "user_1 win the game"
                break            
            else:
                pass
                #print("something wrong while calculating the user 1 statue")
                
    #here i will chech if the random input from the computer make a good movement and win the game or just random move from computer 
    elif user ==3:
        print("I am inside computer  for cheching  ")
        print(f"the result is {result}")
        for i in range(8):
            if (pos[0] == pos[1]==pos[2] == "O"):
                print("Computer  win the game1")
                result= "Computer win the game"
                break
            elif(pos[3] == pos[4]==pos[5] == "O"):
                print("user : 2 win the game2")
                result= "Computer win the game"
                break
            
            elif(pos[6] == pos[7]==pos[8] == "O"):
                print("user : 2 win the game3")
                result= "Computer win the game"
                break
                
            elif(pos[0] == pos[3]==pos[6] == "O"):
                print("user : 2 win the game4")
                result= "Computer win the game"
                break
            
            elif(pos[1] == pos[4]==pos[7] == "O"):
                print("user : 2 win the game5")
                result= "Computer win the game"
                break
            elif(pos[2] == pos[5]==pos[8] == "O"):
                print("user : 2 win the game6")
                result= "Computer win the game"
                break
            
            elif(pos[0] == pos[4]==pos[8] == "O"):
                print("user : 2 win the game7")
                result= "Computer win the game"
                break
            
            elif(pos[2] == pos[4]==pos[6] == "O"):
                print("user : 2 win the game8")
                result= "Computer win the game"
                break
            else:
                pass
                #print("something wrong while calculating the user 2 statue")
        
        
    
    else:
        print(" I can not find out who is the winner ")
    
    print(f"the result in the last if is::: {result}")
    return result

# %%
def play_user1(user,result):
    user_input=int(input("User 1   Play  "))
    update_table(user_input,user)
    show_table(pos)
    result=check_winner(pos,user,result)
    print(f"the result in the play _user1 functions is ::{result}")
    return result

# %%
import random 
def play_computer(user,result):
    
    print(f"the all position is :{pos}")
    position_empty=[]
    for value in pos: 
        if (value == "X") or (value == "O"):
            print ("X or O value ")
        else:
            position_empty.append(value)
            print("value is number ")
    print(f"empty postion is {position_empty}")
    #the computer input 
    comp_input=random.choice(position_empty)
    print (f"computer will play   {comp_input}")
    update_table(comp_input,user)
    show_table(pos)
    result=check_winner(pos,user,result)
    return result

# %%
global user
global pos

pos=[1,2,3,4,5,6,7,8,9]
show_table(pos)
result ="No one win the game, continue playing "    

for i in range(5):
    print(f"  Round : {i+1}  ,in the game ")
    user=1
    result =play_user1(user,result)
    print(f"the result in the main_player1 is : {result}")
    
    if result == "user_1 win the game":
        print("user_1 win the game,,  I will going to finish the game ")
        break
    else:
        print ("the game is still working ")
        
    user=3
    #user =3 mean the computer will play 
    result=play_computer(user,result)
    print(f"the result in the main_computer is : {result}")
    if result == "Computer win the game":
        print("Computer win the game,,  I will going to finish the game ")
        break
    else:
        print ("the game is still working ")

print(" The game is  finished ")
# Out:
# _________________________________
# |          |          |          |
# |     1    |     2    |     3    |
# |          |          |          |
# _________________________________
# |          |          |          |
# |     4    |     5    |     6    |
# |          |          |          |
# _________________________________
# |          |          |          |
# |     7    |     8    |     9    |
# |          |          |          |
# _________________________________
#
#   Round : 1  ,in the game
# User 1   Play  1
#
# _________________________________
# |          |          |          |
# |     X    |     2    |     3    |
# |          |          |          |
# _________________________________
# |          |          |          |
# |     4    |     5    |     6    |
# |          |          |          |
# _________________________________
# |          |          |          |
# |     7    |     8    |     9    |
# |          |          |          |
# _________________________________
#
# ['X', 2, 3, 4, 5, 6, 7, 8, 9]
# user value is 1
# I am inside user 1 for checking
# the result is No one win the game, continue playing
# the result in the last if is::: No one win the game, continue playing
# the result in the play _user1 functions is ::No one win the game, continue playing
# the result in the main_player1 is : No one win the game, continue playing
# the game is still working
# the all position is :['X', 2, 3, 4, 5, 6, 7, 8, 9]
# X or O value
# value is number
# value is number
# value is number
# value is number
# value is number
# value is number
# value is number
# value is number
# empty postion is [2, 3, 4, 5, 6, 7, 8, 9]
# computer will play   2
#
# _________________________________
# |          |          |          |
# |     X    |     O    |     3    |
# |          |          |          |
# _________________________________
# |          |          |          |
# |     4    |     5    |     6    |
# |          |          |          |
# _________________________________
# |          |          |          |
# |     7    |     8    |     9    |
# |          |          |          |
# _________________________________
#
# ['X', 'O', 3, 4, 5, 6, 7, 8, 9]
# user value is 3
# I am inside computer  for cheching
# the result is No one win the game, continue playing
# the result in the last if is::: No one win the game, continue playing
# the result in the main_computer is : No one win the game, continue playing
# the game is still working
#   Round : 2  ,in the game
# User 1   Play  4
#
# _________________________________
# |          |          |          |
# |     X    |     O    |     3    |
# |          |          |          |
# _________________________________
# |          |          |          |
# |     X    |     5    |     6    |
# |          |          |          |
# _________________________________
# |          |          |          |
# |     7    |     8    |     9    |
# |          |          |          |
# _________________________________
#
# ['X', 'O', 3, 'X', 5, 6, 7, 8, 9]
# user value is 1
# I am inside user 1 for checking
# the result is No one win the game, continue playing
# the result in the last if is::: No one win the game, continue playing
# the result in the play _user1 functions is ::No one win the game, continue playing
# the result in the main_player1 is : No one win the game, continue playing
# the game is still working
# the all position is :['X', 'O', 3, 'X', 5, 6, 7, 8, 9]
# X or O value
# X or O value
# value is number
# X or O value
# value is number
# value is number
# value is number
# value is number
# value is number
# empty postion is [3, 5, 6, 7, 8, 9]
# computer will play   8
#
# _________________________________
# |          |          |          |
# |     X    |     O    |     3    |
# |          |          |          |
# _________________________________
# |          |          |          |
# |     X    |     5    |     6    |
# |          |          |          |
# _________________________________
# |          |          |          |
# |     7    |     O    |     9    |
# |          |          |          |
# _________________________________
#
# ['X', 'O', 3, 'X', 5, 6, 7, 'O', 9]
# user value is 3
# I am inside computer  for cheching
# the result is No one win the game, continue playing
# the result in the last if is::: No one win the game, continue playing
# the result in the main_computer is : No one win the game, continue playing
# the game is still working
#   Round : 3  ,in the game
# User 1   Play  7
#
# _________________________________
# |          |          |          |
# |     X    |     O    |     3    |
# |          |          |          |
# _________________________________
# |          |          |          |
# |     X    |     5    |     6    |
# |          |          |          |
# _________________________________
# |          |          |          |
# |     X    |     O    |     9    |
# |          |          |          |
# _________________________________
#
# ['X', 'O', 3, 'X', 5, 6, 'X', 'O', 9]
# user value is 1
# I am inside user 1 for checking
# the result is No one win the game, continue playing
# user : 1 win the game4
# the result in the last if is::: user_1 win the game
# the result in the play _user1 functions is ::user_1 win the game
# the result in the main_player1 is : user_1 win the game
# user_1 win the game,,  I will going to finish the game
#  The game is  finished
